# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Table 1. Real Gross Domestic Product, by County, 2018–2021
df = pd.read_csv("lagdp1222.csv")
df2=df.dropna()
gdpdf = df2.rename(columns={"Unnamed: 0": "County"})

header = ['Ohio Counties', 'Real GDP (2018)', 'Real GDP (2019)', 'Real GDP (2020)', 'Real GDP (2021)', 'Real GDP Rank In State (2021)','Percent change (2019)', 
          'Percent change (2020)', 'Percent change (2021', 'Percent change Rank In State (2021)']

# %%
gdpdf.columns=header
gdpdf
# Out:
#    Ohio Counties Real GDP (2018) Real GDP (2019) Real GDP (2020)  \
# 3          Adams         872,694         675,829         681,273
# 4          Allen       7,597,930       7,558,271       7,253,048
# 5        Ashland       1,571,586       1,579,051       1,606,240
# 6      Ashtabula       2,841,614       2,855,855       2,734,051
# 7         Athens       1,883,444       1,929,652       1,829,060
# ..           ...             ...             ...             ...
# 86    Washington       3,107,136       3,269,479       3,146,595
# 87         Wayne       5,728,498       6,008,910       5,978,653
# 88      Williams       1,597,822       1,687,734       1,617,271
# 89          Wood       6,558,266       6,855,022       6,544,209
# 90       Wyandot         950,167         957,106         952,109
#
#    Real GDP (2021) Real GDP Rank In State (2021) Percent change (2019)  \
# 3          717,219                            80                 -22.6
# ...

# %%
gdpdf['Banned or not'] = vList

# %%
gdpdf2 = gdpdf.replace(',','', regex=True)
gdpdf2.iloc[:, 1:] = gdpdf2.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
gdpdf.to_csv('GDPdata.csv')
gdpdf2
# Out:
#    Ohio Counties  Real GDP (2018)  Real GDP (2019)  Real GDP (2020)  \
# 3          Adams           872694           675829           681273
# 4          Allen          7597930          7558271          7253048
# 5        Ashland          1571586          1579051          1606240
# 6      Ashtabula          2841614          2855855          2734051
# 7         Athens          1883444          1929652          1829060
# ..           ...              ...              ...              ...
# 86    Washington          3107136          3269479          3146595
# 87         Wayne          5728498          6008910          5978653
# 88      Williams          1597822          1687734          1617271
# 89          Wood          6558266          6855022          6544209
# 90       Wyandot           950167           957106           952109
#
#     Real GDP (2021)  Real GDP Rank In State (2021)  Percent change (2019)  \
# 3            717219                             80                  -22.6
# ...

# %%
gdpdf3 = gdpdf2.iloc[:, 0:]
gdpdf3
# Out:
#    Ohio Counties  Real GDP (2018)  Real GDP (2019)  Real GDP (2020)  \
# 3          Adams           872694           675829           681273
# 4          Allen          7597930          7558271          7253048
# 5        Ashland          1571586          1579051          1606240
# 6      Ashtabula          2841614          2855855          2734051
# 7         Athens          1883444          1929652          1829060
# ..           ...              ...              ...              ...
# 86    Washington          3107136          3269479          3146595
# 87         Wayne          5728498          6008910          5978653
# 88      Williams          1597822          1687734          1617271
# 89          Wood          6558266          6855022          6544209
# 90       Wyandot           950167           957106           952109
#
#     Real GDP (2021)  Real GDP Rank In State (2021)  Percent change (2019)  \
# 3            717219                             80                  -22.6
# ...

# %%
# Top 20 Counties with highest Real GDP 
fig, ax = plt.subplots(figsize=(16,6))
top_gdp_counties = gdpdf2.sort_values('Real GDP (2021)',ascending=False).head(20)
mean = pd.DataFrame({'Ohio':['County mean'], 'Real GDP (2021)':[gdpdf2['Real GDP (2021)'].mean()]})
gdps = pd.concat([top_gdp_counties[['Ohio Counties','Real GDP (2021)', 'Banned or not']],mean],ignore_index=True)

labels=["No Ban","Ban"]

sns.barplot(x='Ohio Counties',y='Real GDP (2021)',data=gdps, palette='Set1', hue ='Banned or not').set(title='Top 20 Counties with highest Real GDP')
ax.set_xlabel(ax.get_xlabel(),labelpad=15)
ax.set_ylabel(ax.get_ylabel(),labelpad=30)
ax.xaxis.label.set_fontsize(16)
ax.yaxis.label.set_fontsize(16)
plt.xticks(rotation=90)

h, l = ax.get_legend_handles_labels()
ax.legend(h, labels)

plt.show()

fig.savefig("GDPplot.jpg")
